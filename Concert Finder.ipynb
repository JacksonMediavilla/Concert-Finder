# %%
import requests
from bs4 import BeautifulSoup
from enum import Enum
from datetime import datetime
import json
from tabulate import tabulate

red_rocks_url = 'https://www.redrocksonline.com/events/'
mission_ballroom_url = 'https://www.missionballroom.com/data/events-index.json'
tracks_file = 'tracks.json'

# vinyl, temple, church, ogden, fillmore, cervantes, summit, marquis
class Location(Enum):
    REDROCKS = 'Red Rocks'
    MISSION_BALLROOM = 'Mission Ballroom'

class Event:
    def __init__(self, date, headliner, openers, location):
        self.date = date
        self.headliner = headliner
        self.openers = openers
        self.location = location

def GetRedRocksEvents():
    events = []
    response = requests.get(red_rocks_url)
    
    if response.status_code == 200:
        soup = BeautifulSoup(response.text, 'html.parser')
    
        for event in soup.find_all('div', 'card-content'):
            date_text = event.contents[1].text.strip()
            if ' pm' not in date_text:
                continue #logic to skip duplicate entries - TODO: investigate and refactor
            date = datetime.strptime(date_text, "%a, %b %d, %I:%M %p")
            date = date.replace(year=datetime.now().year)
            headliner = event.contents[3].text.strip()
            openers = ''
            if len(event.contents) > 5:
                openers = event.contents[5].text.strip()
            events.append(Event(date, headliner, openers, Location.REDROCKS))
    else:
        print(f'Failed to retrieve page. Status code: {response.status_code}')

    return events

def GetMissionBallroomEvents():
    events = []
    response = requests.get(mission_ballroom_url)
    
    if response.status_code == 200:
        data = response.json()

        for event in data:
            date_text = f"{event['date']}, {event['doorDateTime']}"
            date = datetime.strptime(date_text, "%A, %B %d, %Y, %I:%M%p")
            headliner = event['title']
            openers = event['subtitle']
            events.append(Event(date, headliner, openers, Location.MISSION_BALLROOM))
    else:
        print(f'Failed to retrieve page. Status code: {response.status_code}')

    return events

def ReadTracksFromFile():
    with open(tracks_file, 'r') as file:
        return json.load(file)

def GetArtistSaveCounts(tracks):
    artists = {}

    for track in tracks:
        for artist in track['track']['artists']:
            name = artist['name']
            count = artists.get(name)
            if count is not None:
                artists[name] = count + 1
            else:
                artists[name] = 1

    # return sorted dictionary of artists in descending order of track save count
    return dict(sorted(artists.items(), key=lambda item: item[1], reverse=True))

def GetRelevantShows(shows, artists):
    relevant_shows = {}
    for key, value in artists.items():
        for show in shows:
            openers = [item.strip().lower() for item in show.openers.split(',')]
            key_lower = key.lower()
            if key_lower == show.headliner.strip().lower() or key_lower in openers:
                relevance = relevant_shows.get(show)
                if relevance is not None:
                    relevant_shows[show] = relevance + value
                else:
                    relevant_shows[show] = value

    # Return sorted dictionary of shows by descending relevance
    return dict(sorted(relevant_shows.items(), key=lambda item: item[1], reverse=True))

def PrintShows(show_dict):
    rows = [
        [relevance, show.headliner, show.openers, show.date.strftime("%m-%d-%Y %I:%M %p"), show.location.value]
        for show, relevance in show_dict.items()
    ]
    headers = ["Relevance", "Headliner", "Openers", "Date", "Location"]
    print(tabulate(rows, headers=headers, tablefmt="grid", maxcolwidths=50))

all_events = GetRedRocksEvents()
all_events += GetMissionBallroomEvents()
all_tracks = ReadTracksFromFile()
artist_counts = GetArtistSaveCounts(all_tracks)
relevant_shows = GetRelevantShows(all_events, artist_counts)
PrintShows(relevant_shows)
# Out:
# +-------------+-------------------------------+----------------------------------------------------+---------------------+------------------+
# |   Relevance | Headliner                     | Openers                                            | Date                | Location         |
# +=============+===============================+====================================================+=====================+==================+
# |         138 | ZEDS DEAD                     |                                                    | 07-02-2025 06:00 PM | Red Rocks        |
# +-------------+-------------------------------+----------------------------------------------------+---------------------+------------------+
# |         138 | ZEDS DEAD                     |                                                    | 07-03-2025 06:00 PM | Red Rocks        |
# +-------------+-------------------------------+----------------------------------------------------+---------------------+------------------+
# |         105 | Rezz                          | AC Slater, AHEE, Digital Ethos, Curra              | 10-19-2025 05:00 PM | Red Rocks        |
# +-------------+-------------------------------+----------------------------------------------------+---------------------+------------------+
# |          93 | Virtual Riot                  | Eliminate, ZEKE BEATS, UBUR b2b Phiso, RANKZ       | 05-24-2025 07:00 PM | Mission Ballroom |
# +-------------+-------------------------------+----------------------------------------------------+---------------------+------------------+
# |          83 | Rezz                          | YDG, Shadient, NotLö, Tinykvt                      | 10-18-2025 06:00 PM | Red Rocks        |
# +-------------+-------------------------------+----------------------------------------------------+---------------------+------------------+
# |          75 | Apashe                        | Flux Pavilion, Josh Teed                           | 11-02-2025 07:00 PM | Red Rocks        |
# +-------------+-------------------------------+----------------------------------------------------+---------------------+------------------+
# |          57 | Ganja White Night             | LYNY, Mary Droppinz, Chef Boyarbeatz, Thred        | 05-31-2025 05:00 PM | Red Rocks        |
# +-------------+-------------------------------+----------------------------------------------------+---------------------+------------------+
# |          51 | Ganja White Night             | Smoakland, Xotix, Stylust Beats, Myrias            | 05-30-2025 06:30 PM | Mission Ballroom |
# +-------------+-------------------------------+----------------------------------------------------+---------------------+------------------+
# |          47 | SVDDEN DEATH presents VOYD    | Alice Glass, Simula, Witching Hour, Mythm,         | 11-13-2025 06:00 PM | Red Rocks        |
# |             |                               | Executioner                                        |                     |                  |
# +-------------+-------------------------------+----------------------------------------------------+---------------------+------------------+
# |          40 | deadmau5                      |                                                    | 11-07-2025 06:00 PM | Red Rocks        |
# +-------------+-------------------------------+----------------------------------------------------+---------------------+------------------+
# |          40 | deadmau5                      |                                                    | 11-08-2025 06:00 PM | Red Rocks        |
# +-------------+-------------------------------+----------------------------------------------------+---------------------+------------------+
# |          36 | Tape B                        | Cool Customer, MPH, STVSH, KNOW GOOD, Richard      | 10-10-2025 06:00 PM | Red Rocks        |
# |             |                               | Finger                                             |                     |                  |
# +-------------+-------------------------------+----------------------------------------------------+---------------------+------------------+
# |          29 | Skrillex                      |                                                    | 05-13-2025 06:30 PM | Red Rocks        |
# +-------------+-------------------------------+----------------------------------------------------+---------------------+------------------+
# |          24 | Big Gigantic                  | Maddy O'Neal                                       | 09-27-2025 06:00 PM | Red Rocks        |
# +-------------+-------------------------------+----------------------------------------------------+---------------------+------------------+
# |          18 | Empire Of The Sun             | Roi Turbo                                          | 04-28-2025 08:00 PM | Red Rocks        |
# +-------------+-------------------------------+----------------------------------------------------+---------------------+------------------+
# |          18 | ALLEYCVT                      | Sumthin Sumthin, Dennett, Seth David, Machaki,     | 12-06-2025 07:00 PM | Mission Ballroom |
# |             |                               | Maddelik                                           |                     |                  |
# +-------------+-------------------------------+----------------------------------------------------+---------------------+------------------+
# |          14 | SVDDEN DEATH                  | Zomboy, Prosecute, Nimda, Bejalvin, STVG           | 11-14-2025 06:00 PM | Red Rocks        |
# +-------------+-------------------------------+----------------------------------------------------+---------------------+------------------+
# |          12 | Malaa                         | Omnom, Dillon Nathaniel, Phat Jazz                 | 05-23-2025 07:00 PM | Mission Ballroom |
# +-------------+-------------------------------+----------------------------------------------------+---------------------+------------------+
# |           9 | Madeon                        |                                                    | 10-03-2025 07:00 PM | Red Rocks        |
# +-------------+-------------------------------+----------------------------------------------------+---------------------+------------------+
# |           8 | Martin Garrix                 |                                                    | 10-23-2025 07:00 PM | Red Rocks        |
# +-------------+-------------------------------+----------------------------------------------------+---------------------+------------------+
# |           8 | Martin Garrix                 |                                                    | 10-24-2025 07:00 PM | Red Rocks        |
# +-------------+-------------------------------+----------------------------------------------------+---------------------+------------------+
# |           7 | Opiuo + The Opulent Orchestra | Detox Unit, Resonant Language, Duffrey, Motifv     | 05-11-2025 05:00 PM | Red Rocks        |
# +-------------+-------------------------------+----------------------------------------------------+---------------------+------------------+
# |           6 | Daily Bread                   | RJD2, Artifakts, Empress Rah                       | 10-25-2025 05:30 PM | Red Rocks        |
# +-------------+-------------------------------+----------------------------------------------------+---------------------+------------------+
# |           5 | Daily Bread                   | Big Boi, Late Night Radio, Cloud Conductor         | 10-26-2025 05:30 PM | Red Rocks        |
# +-------------+-------------------------------+----------------------------------------------------+---------------------+------------------+
# |           4 | Timmy Trumpet                 | Yellow Claw, Sunday Scaries                        | 08-22-2025 07:00 PM | Mission Ballroom |
# +-------------+-------------------------------+----------------------------------------------------+---------------------+------------------+
# |           3 | Halsey                        | Magdalena Bay, flowerolove                         | 06-22-2025 07:00 PM | Red Rocks        |
# +-------------+-------------------------------+----------------------------------------------------+---------------------+------------------+
# |           3 | Carl Cox Evolution Live       | Vintage Culture, ANNA, Bontan, The Bordas Brothers | 10-13-2025 06:00 PM | Red Rocks        |
# +-------------+-------------------------------+----------------------------------------------------+---------------------+------------------+
# |           3 | Justice                       | Fcukers                                            | 05-25-2025 07:30 PM | Red Rocks        |
# +-------------+-------------------------------+----------------------------------------------------+---------------------+------------------+
# |           3 | Russ                          | Big Sean, Sabrina Claudio                          | 07-08-2025 07:00 PM | Red Rocks        |
# +-------------+-------------------------------+----------------------------------------------------+---------------------+------------------+
# |           2 | Thievery Corporation          | Beats Antique, Moontricks                          | 06-04-2025 06:30 PM | Red Rocks        |
# +-------------+-------------------------------+----------------------------------------------------+---------------------+------------------+
# |           2 | Lane 8                        | Le Youth, Ashibah b2b Rinzen                       | 10-11-2025 06:00 PM | Red Rocks        |
# +-------------+-------------------------------+----------------------------------------------------+---------------------+------------------+
# |           2 | Charley Crockett              | Chaparelle, Rattlesnake Milk                       | 06-25-2025 07:00 PM | Red Rocks        |
# +-------------+-------------------------------+----------------------------------------------------+---------------------+------------------+
# |           1 | LCD Soundsystem               | TV On The Radio                                    | 08-13-2025 07:30 PM | Red Rocks        |
# +-------------+-------------------------------+----------------------------------------------------+---------------------+------------------+
# |           1 | Hippie Sabotage – Rescheduled | Two Feet, Kal Banx                                 | 08-22-2025 07:00 PM | Red Rocks        |
# +-------------+-------------------------------+----------------------------------------------------+---------------------+------------------+
# |           1 | Emperor                       | Wayfarer                                           | 05-13-2025 07:00 PM | Mission Ballroom |
# +-------------+-------------------------------+----------------------------------------------------+---------------------+------------------+
# |           1 | SAINt JHN                     | Jordan Hawkins, Keenan Trevon                      | 04-27-2025 07:00 PM | Mission Ballroom |
# +-------------+-------------------------------+----------------------------------------------------+---------------------+------------------+
# |           1 | Teddy Swims                   | Cian Ducrot                                        | 08-26-2025 08:00 PM | Red Rocks        |
# +-------------+-------------------------------+----------------------------------------------------+---------------------+------------------+
# |           1 | TWO FRIENDS                   | Laszewo, MC4D, Beachcrimes                         | 04-30-2025 07:00 PM | Red Rocks        |
# +-------------+-------------------------------+----------------------------------------------------+---------------------+------------------+
# |           1 | The Kooks                     | lovelytheband                                      | 06-13-2025 08:00 PM | Mission Ballroom |
# +-------------+-------------------------------+----------------------------------------------------+---------------------+------------------+
# |           1 | TobyMac                       | Switchfoot, Cochren & Co.                          | 05-07-2025 07:00 PM | Red Rocks        |
# +-------------+-------------------------------+----------------------------------------------------+---------------------+------------------+
# |           1 | My Morning Jacket             | Melt                                               | 08-15-2025 07:30 PM | Red Rocks        |
# +-------------+-------------------------------+----------------------------------------------------+---------------------+------------------+
# |           1 | My Morning Jacket             | Melt                                               | 08-16-2025 07:30 PM | Red Rocks        |
# +-------------+-------------------------------+----------------------------------------------------+---------------------+------------------+
# |           1 | Slightly Stoopid              | Iration, Collie Buddz, Little Stranger             | 08-09-2025 05:30 PM | Red Rocks        |
# +-------------+-------------------------------+----------------------------------------------------+---------------------+------------------+
# |           1 | Tennis                        |                                                    | 08-26-2025 07:00 PM | Mission Ballroom |
# +-------------+-------------------------------+----------------------------------------------------+---------------------+------------------+
# |           1 | Tash Sultana                  |                                                    | 06-20-2025 08:00 PM | Red Rocks        |
# +-------------+-------------------------------+----------------------------------------------------+---------------------+------------------+
# |           1 | Rainbow Kitten Surprise       | Medium Build                                       | 09-08-2025 06:00 PM | Red Rocks        |
# +-------------+-------------------------------+----------------------------------------------------+---------------------+------------------+
# |           1 | Reggae On The Rocks 2025      | Rebelution, SOJA, Tarrus Riley, Kabaka Pyramid,    | 08-23-2025 03:00 PM | Red Rocks        |
# |             |                               | Rik Jam, Judge Roughneck                           |                     |                  |
# +-------------+-------------------------------+----------------------------------------------------+---------------------+------------------+
# |           1 | Dirty Heads                   | Rome, Tropidelic                                   | 06-26-2025 07:00 PM | Red Rocks        |
# +-------------+-------------------------------+----------------------------------------------------+---------------------+------------------+
