# %%
import requests
from bs4 import BeautifulSoup
from enum import Enum
from datetime import datetime
import json
from tabulate import tabulate
import re
from selenium import webdriver
from selenium.webdriver.chrome.options import Options
from selenium.webdriver.common.by import By

red_rocks_url = 'https://www.redrocksonline.com/events/'
mission_ballroom_url = 'https://www.missionballroom.com/data/events-index.json'
vinyl_url = 'https://vinylnightclub.com/upcoming-denver-colorado-nightlife-club-events-shows-concerts-near-me/'
church_url = 'https://churchnightclubco.com/upcoming-underground-club-events-electronic-dance-music-near-me-denver-co/'
ogden_url = 'https://aegwebprod.blob.core.windows.net/json/events/7/events.json'
reelworks_url = 'https://reelworksdenver.com/events/'
meow_wolf_url = 'https://tickets.meowwolf.com/events/denver/'
tracks_file = 'tracks.json'

# fake headers to use when a site requires them
fake_headers = {
    "User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/114.0.0.0 Safari/537.36",
    "Accept-Language": "en-US,en;q=0.9",
    "Accept-Encoding": "gzip, deflate, br",
    "Connection": "keep-alive",
    "Upgrade-Insecure-Requests": "1",
    "TE": "Trailers"
}

class Location(Enum):
    REDROCKS = 'Red Rocks'
    MISSION_BALLROOM = 'Mission Ballroom'
    VINYL = 'Club Vinyl'
    CHURCH = 'The Church Nightclub'
    OGDEN = 'Ogden Theatre'
    REELWORKS = 'ReelWorks'
    MEOW_WOLF = 'Meow Wolf'

class Event:
    def __init__(self, date, headliner, openers, location):
        self.date = date
        self.headliner = headliner
        self.openers = openers
        self.location = location

    def __str__(self):
            return (
                f"Date: {self.date.strftime("%m-%d-%Y") if self.date else 'TBD'}\n"
                f"Headliner: {self.headliner}\n"
                f"Openers: {self.openers}\n"
                f"Location: {self.location.value}"
            )

def get_red_rocks_events():
    events = []
    response = requests.get(red_rocks_url)
    
    if response.status_code == 200:
        soup = BeautifulSoup(response.text, 'html.parser')
    
        for event in soup.find_all('div', 'card-content'):
            date_text = event.find('div', class_='date').text.strip()
            if ' pm' not in date_text:
                continue #logic to skip duplicate entries - TODO: investigate and refactor
            date = datetime.strptime(date_text, "%a, %b %d, %I:%M %p")
            date = date.replace(year=datetime.now().year)
            headliner = event.find('h3', class_='card-title').text.strip()
            openers = ''
            if event.find('p', class_='hide-mobile'):
                openers = event.find('p', class_='hide-mobile').text.strip()
            events.append(Event(date, headliner, openers, Location.REDROCKS))
    else:
        print(f'Failed to retrieve page. Status code: {response.status_code}')

    return events

def get_mission_ballroom_events():
    events = []
    response = requests.get(mission_ballroom_url)
    
    if response.status_code == 200:
        data = response.json()

        for event in data:
            date_text = f"{event['date']}, {event['doorDateTime']}"
            date = datetime.strptime(date_text, "%A, %B %d, %Y, %I:%M%p")
            headliner = event['title']
            openers = event['subtitle']
            events.append(Event(date, headliner, openers, Location.MISSION_BALLROOM))
    else:
        print(f'Failed to retrieve page. Status code: {response.status_code}')

    return events

def get_vinyl_events():
    return get_club_events(vinyl_url, Location.VINYL)

def get_church_events():
    return get_club_events(church_url, Location.CHURCH)

def get_club_events(url, club_name):
    events = []
    response = requests.get(url, headers=fake_headers)
    
    if response.status_code == 200:
        soup = BeautifulSoup(response.text, 'html.parser')

        event_divs = soup.find_all('div', class_='events__item')

        for event in event_divs:
            date_text = event.find('div', class_='event__date event__date-list').text.strip()
            date = datetime.strptime(date_text, "%m.%d.%y")
            title = event.find('span', class_='event__content-title').text.strip()
            events.append(Event(date, title, '', club_name))
    else:
        print(f'Failed to retrieve page. Status code: {response.status_code}')

    return events

def get_ogden_events():
    events = []
    response = requests.get(ogden_url)
    
    if response.status_code == 200:
        data = response.json()
        events_json = data['events']
        for event in events_json:
            date_text = event['eventDateTime']
            date = datetime.fromisoformat(date_text) if date_text != 'TBD' else None
            headliner = event['title']['headlinersText']
            openers = event['title']['supportingText'] or ''
            events.append(Event(date, headliner, openers, Location.OGDEN))
    else:
        print(f'Failed to retrieve page. Status code: {response.status_code}')

    return events

def get_reelworks_events():
    events = []
    response = requests.get(reelworks_url, headers=fake_headers)
    
    if response.status_code == 200:
        soup = BeautifulSoup(response.text, 'html.parser')
    
        for event in soup.find_all('div', class_='event-item-info'):
            date_text = event.find('h3').text.strip()
            date = datetime.strptime(date_text, "%A, %b %d, %Y")
            headliner = event.find('h1').text.strip()
            openers = ''
            if event.find('h4'):
                openers = event.find('h4').text.strip() #TODO: handle different formatting for openers
            events.append(Event(date, headliner, openers, Location.REELWORKS))
    else:
        print(f'Failed to retrieve page. Status code: {response.status_code}')
    
    return events

def get_meow_wolf_events():
    events = []
    
    options = Options()
    options.add_argument('--headless')
    driver = webdriver.Chrome(options=options)
    driver.get(meow_wolf_url)
    driver.implicitly_wait(10) 
    driver.find_element(By.CLASS_NAME, "details__Uo5Th") # Wait for JavaScript to load the content
    html = driver.page_source
    
    soup = BeautifulSoup(html, 'html.parser')
    for event in soup.find_all('div', class_='details__Uo5Th'):
        date_text = event.find('div', class_='date__3PFQZ').text.strip().replace("Doors @ ", "")
        cleaned_date_text = re.sub(r'(\d+)(st|nd|rd|th)', r'\1', date_text)
        date = datetime.strptime(cleaned_date_text, "%b %d %I:%M %p")
        date = date.replace(year=datetime.now().year)
        headliner = event.find('div', class_='title__1ZRxy').text.strip()
        openers = ''
        if event.find('div', class_='guest-acts___tZRb'):
            openers = event.find('div', class_='guest-acts___tZRb').text.strip().replace(" | ", ", ")
        events.append(Event(date, headliner, openers, Location.MEOW_WOLF))

    driver.quit()
    return events

def get_all_events():
    events = get_red_rocks_events()
    events += get_mission_ballroom_events()
    events += get_vinyl_events()
    events += get_church_events()
    events += get_ogden_events()
    events += get_reelworks_events()
    events += get_meow_wolf_events()
    return events

def read_tracks_from_file():
    with open(tracks_file, 'r') as file:
        return json.load(file)

def get_artist_save_counts(tracks):
    artists = {}

    for track in tracks:
        for artist in track['track']['artists']:
            name = artist['name']
            count = artists.get(name)
            if count is not None:
                artists[name] = count + 1
            else:
                artists[name] = 1

    # return sorted dictionary of artists in descending order of track save count
    return dict(sorted(artists.items(), key=lambda item: item[1], reverse=True))

def artist_match(artist, show_data):
    artist_lower = artist.strip().lower()
    show_data_lower = show_data.strip().lower()

    # check if strings are the same
    if artist_lower == show_data_lower:
        return True

    # check if 'artist' is an isolated string in the show data
    pattern = rf'(?<![a-z]){re.escape(artist_lower)}(?![a-z])'
    return re.search(pattern, show_data_lower) is not None

def get_relevant_shows(shows, artists):
    relevant_shows = {}
    for key, value in artists.items():
        for show in shows:
            if artist_match(key, show.headliner) or artist_match(key, show.openers):
                relevance = relevant_shows.get(show)
                if relevance is not None:
                    relevant_shows[show] = relevance + value
                else:
                    relevant_shows[show] = value

    # Return sorted dictionary of shows by descending relevance
    return dict(sorted(relevant_shows.items(), key=lambda item: item[1], reverse=True))

def print_shows(show_dict):
    rows = [
        [relevance, show.headliner, show.openers, show.date.strftime("%m-%d-%Y") if show.date else 'TBD', show.location.value]
        for show, relevance in show_dict.items()
    ]
    headers = ["Relevance", "Headliner", "Openers / Info", "Date", "Location"]
    print(tabulate(rows, headers=headers, tablefmt="grid", maxcolwidths=40))

all_events = get_all_events()
all_tracks = read_tracks_from_file()
artist_counts = get_artist_save_counts(all_tracks)
relevant_shows = get_relevant_shows(all_events, artist_counts)
print_shows(relevant_shows)
# Out:
# +-------------+-----------------------------------------+------------------------------------------+------------+----------------------+
# |   Relevance | Headliner                               | Openers / Info                           | Date       | Location             |
# +=============+=========================================+==========================================+============+======================+
# |         138 | ZEDS DEAD                               |                                          | 07-02-2025 | Red Rocks            |
# +-------------+-----------------------------------------+------------------------------------------+------------+----------------------+
# |         138 | ZEDS DEAD                               |                                          | 07-03-2025 | Red Rocks            |
# +-------------+-----------------------------------------+------------------------------------------+------------+----------------------+
# |         119 | Sub Focus & Dimension & Culture Shock & |                                          | 10-30-2025 | Red Rocks            |
# |             | 1991                                    |                                          |            |                      |
# +-------------+-----------------------------------------+------------------------------------------+------------+----------------------+
# |         119 | Sub Focus, Dimension, Culture Shock,    |                                          | 10-30-2025 | Mission Ballroom     |
# |             | 1991                                    |                                          |            |                      |
# +-------------+-----------------------------------------+------------------------------------------+------------+----------------------+
# |         105 | Rezz                                    | AC Slater, AHEE, Digital Ethos, Curra    | 10-19-2025 | Red Rocks            |
# +-------------+-----------------------------------------+------------------------------------------+------------+----------------------+
# |         104 | LSZEE                                   | LSDREAM & CloZee with support by Effin,  | 06-19-2025 | Mission Ballroom     |
# |             |                                         | Mocha, Lucid Slip                        |            |                      |
# +-------------+-----------------------------------------+------------------------------------------+------------+----------------------+
# |         104 | LSZEE                                   | LSDREAM & CloZee with support by         | 06-21-2025 | Mission Ballroom     |
# |             |                                         | Effin,Mocha, Lucid Slip                  |            |                      |
# +-------------+-----------------------------------------+------------------------------------------+------------+----------------------+
# |          83 | Rezz                                    | YDG, Shadient, NotLö, Tinykvt            | 10-18-2025 | Red Rocks            |
# +-------------+-----------------------------------------+------------------------------------------+------------+----------------------+
# |          81 | Apashe                                  | Flux Pavilion, Josh Teed                 | 11-02-2025 | Red Rocks            |
# +-------------+-----------------------------------------+------------------------------------------+------------+----------------------+
# |          73 | LSZEE                                   | LSDREAM & CloZee with support by ASHEZ,  | 06-20-2025 | Mission Ballroom     |
# |             |                                         | LIL FISH, HABITAAT                       |            |                      |
# +-------------+-----------------------------------------+------------------------------------------+------------+----------------------+
# |          73 | LSZEE                                   | LSDREAM & CloZee with support by ASHEZ,  | 06-22-2025 | Mission Ballroom     |
# |             |                                         | LIL FISH, HABITAAT                       |            |                      |
# +-------------+-----------------------------------------+------------------------------------------+------------+----------------------+
# |          72 | SLANDER Presents: CODE RED              | William Black b2b Blanke, Fairlane b2b   | 07-17-2025 | Red Rocks            |
# |             |                                         | Pauline Herr, Ivory b2b Perry Wayne,     |            |                      |
# |             |                                         | Nejvex                                   |            |                      |
# +-------------+-----------------------------------------+------------------------------------------+------------+----------------------+
# |          61 | Don Diablo                              |                                          | 06-13-2025 | The Church Nightclub |
# +-------------+-----------------------------------------+------------------------------------------+------------+----------------------+
# |          60 | Rezz 2-Day Pass                         |                                          | 10-18-2025 | Red Rocks            |
# +-------------+-----------------------------------------+------------------------------------------+------------+----------------------+
# |          60 | Rezz 2-Day Pass                         |                                          | 10-19-2025 | Red Rocks            |
# +-------------+-----------------------------------------+------------------------------------------+------------+----------------------+
# |          59 | Ganja White Night                       | LYNY, Mary Droppinz, Chef Boyarbeatz,    | 05-31-2025 | Red Rocks            |
# |             |                                         | Thred                                    |            |                      |
# +-------------+-----------------------------------------+------------------------------------------+------------+----------------------+
# |          58 | Ganja White Night                       | Smoakland, Xotix, Stylust Beats, Myrias  | 05-30-2025 | Mission Ballroom     |
# +-------------+-----------------------------------------+------------------------------------------+------------+----------------------+
# |          51 | SVDDEN DEATH presents VOYD              | Alice Glass, Simula, Witching Hour,      | 11-13-2025 | Red Rocks            |
# |             |                                         | Mythm, Executioner                       |            |                      |
# +-------------+-----------------------------------------+------------------------------------------+------------+----------------------+
# |          42 | deadmau5                                |                                          | 11-07-2025 | Red Rocks            |
# +-------------+-----------------------------------------+------------------------------------------+------------+----------------------+
# |          42 | deadmau5                                |                                          | 11-08-2025 | Red Rocks            |
# +-------------+-----------------------------------------+------------------------------------------+------------+----------------------+
# |          38 | Galantis PRESENTS MIDSOMMAR – ALL       | Dillon Francis, Forester, Sparkle        | 11-01-2025 | Red Rocks            |
# |             | HALLOWS                                 |                                          |            |                      |
# +-------------+-----------------------------------------+------------------------------------------+------------+----------------------+
# |          38 | Tape B                                  | Cool Customer, MPH, STVSH, KNOW GOOD,    | 10-10-2025 | Red Rocks            |
# |             |                                         | Richard Finger                           |            |                      |
# +-------------+-----------------------------------------+------------------------------------------+------------+----------------------+
# |          24 | Porter Robinson                         | DJ SET                                   | 06-07-2025 | ReelWorks            |
# +-------------+-----------------------------------------+------------------------------------------+------------+----------------------+
# |          24 | Big Gigantic                            | Maddy O'Neal                             | 09-27-2025 | Red Rocks            |
# +-------------+-----------------------------------------+------------------------------------------+------------+----------------------+
# |          22 | ALLEYCVT                                | Sumthin Sumthin, Dennett, Seth David,    | 12-06-2025 | Mission Ballroom     |
# |             |                                         | Machaki, Maddelik                        |            |                      |
# +-------------+-----------------------------------------+------------------------------------------+------------+----------------------+
# |          21 | smith.                                  | VCTRE, Ozztin, MZG Twins, Doses          | 08-22-2025 | Ogden Theatre        |
# +-------------+-----------------------------------------+------------------------------------------+------------+----------------------+
# |          21 | Danceportation                          | What So Not, Elohim, Chet Porter,        | 06-07-2025 | Meow Wolf            |
# |             |                                         | Benson, Quiet Bison                      |            |                      |
# +-------------+-----------------------------------------+------------------------------------------+------------+----------------------+
# |          20 | TVBOO                                   |                                          | 07-10-2025 | The Church Nightclub |
# +-------------+-----------------------------------------+------------------------------------------+------------+----------------------+
# |          17 | Habstrakt                               |                                          | 07-11-2025 | The Church Nightclub |
# +-------------+-----------------------------------------+------------------------------------------+------------+----------------------+
# |          17 | Lumasi                                  | Flozone, Daggz b2b Milano, Wiley,        | 11-29-2025 | Ogden Theatre        |
# |             |                                         | Schmux, Very Sweet                       |            |                      |
# +-------------+-----------------------------------------+------------------------------------------+------------+----------------------+
# |          15 | Grabbitz: Big Epic Tour                 |                                          | 11-06-2025 | The Church Nightclub |
# +-------------+-----------------------------------------+------------------------------------------+------------+----------------------+
# |          14 | SVDDEN DEATH                            | Zomboy, Prosecute, Nimda, Bejalvin, STVG | 11-14-2025 | Red Rocks            |
# +-------------+-----------------------------------------+------------------------------------------+------------+----------------------+
# |          13 | Chris Lake                              | Chris Lorenzo, Aluna, Marco Strous       | 08-30-2025 | Red Rocks            |
# +-------------+-----------------------------------------+------------------------------------------+------------+----------------------+
# |          12 | Alex Warren                             | Michael Sanzone                          | 05-27-2025 | Mission Ballroom     |
# +-------------+-----------------------------------------+------------------------------------------+------------+----------------------+
# |          12 | Alex G                                  | Nilüfer Yanya                            | 09-20-2025 | Mission Ballroom     |
# +-------------+-----------------------------------------+------------------------------------------+------------+----------------------+
# |          10 | Matroda                                 |                                          | 11-22-2025 | ReelWorks            |
# +-------------+-----------------------------------------+------------------------------------------+------------+----------------------+
# |          10 | TRUTH                                   | Mala, Joker, Hypho B2B Coltcuts, Contra  | 11-01-2025 | Mission Ballroom     |
# |             |                                         | B2B Athena                               |            |                      |
# +-------------+-----------------------------------------+------------------------------------------+------------+----------------------+
# |           9 | Madeon                                  |                                          | 10-03-2025 | Red Rocks            |
# +-------------+-----------------------------------------+------------------------------------------+------------+----------------------+
# |           9 | Andy C                                  |                                          | 06-20-2025 | Club Vinyl           |
# +-------------+-----------------------------------------+------------------------------------------+------------+----------------------+
# |           8 | Martin Garrix                           |                                          | 10-23-2025 | Red Rocks            |
# +-------------+-----------------------------------------+------------------------------------------+------------+----------------------+
# |           8 | Martin Garrix                           |                                          | 10-24-2025 | Red Rocks            |
# +-------------+-----------------------------------------+------------------------------------------+------------+----------------------+
# |           8 | Yookie                                  |                                          | 06-12-2025 | The Church Nightclub |
# +-------------+-----------------------------------------+------------------------------------------+------------+----------------------+
# |           8 | Biscits, Devault, Airwolf Paradise      |                                          | 08-09-2025 | Club Vinyl           |
# +-------------+-----------------------------------------+------------------------------------------+------------+----------------------+
# |           8 | Mickman                                 | Resonant Language, Skope, Smigonaut,     | 09-19-2025 | Mission Ballroom     |
# |             |                                         | Mickman Downtempo                        |            |                      |
# +-------------+-----------------------------------------+------------------------------------------+------------+----------------------+
# |           7 | Keys N Krates: Odd Soul Sounds          |                                          | 05-31-2025 | Club Vinyl           |
# +-------------+-----------------------------------------+------------------------------------------+------------+----------------------+
# |           7 | Doctor P                                |                                          | 06-19-2025 | The Church Nightclub |
# +-------------+-----------------------------------------+------------------------------------------+------------+----------------------+
# |           6 | Disclosure                              | DJ SET                                   | 06-13-2025 | ReelWorks            |
# +-------------+-----------------------------------------+------------------------------------------+------------+----------------------+
# |           6 | Daily Bread                             | RJD2, Artifakts, Empress Rah             | 10-25-2025 | Red Rocks            |
# +-------------+-----------------------------------------+------------------------------------------+------------+----------------------+
# |           5 | Levity presents LASERSHIP               |                                          | 11-21-2025 | Mission Ballroom     |
# +-------------+-----------------------------------------+------------------------------------------+------------+----------------------+
# |           5 | Levity presents LASERSHIP               |                                          | 11-22-2025 | Mission Ballroom     |
# +-------------+-----------------------------------------+------------------------------------------+------------+----------------------+
# |           5 | Daily Bread                             | Big Boi, Late Night Radio, Cloud         | 10-26-2025 | Red Rocks            |
# |             |                                         | Conductor                                |            |                      |
# +-------------+-----------------------------------------+------------------------------------------+------------+----------------------+
# |           5 | Pierce The Veil                         | Sleeping With Sirens, Beach Weather      | 06-19-2025 | Red Rocks            |
# +-------------+-----------------------------------------+------------------------------------------+------------+----------------------+
# |           4 | MeSo                                    | Quite Possibly, ABSNT, Puka              | 06-06-2025 | Meow Wolf            |
# +-------------+-----------------------------------------+------------------------------------------+------------+----------------------+
# |           4 | Timmy Trumpet                           | Yellow Claw, Sunday Scaries              | 08-22-2025 | Mission Ballroom     |
# +-------------+-----------------------------------------+------------------------------------------+------------+----------------------+
# |           4 | Lane 8                                  | Le Youth, Ashibah b2b Rinzen             | 10-11-2025 | Red Rocks            |
# +-------------+-----------------------------------------+------------------------------------------+------------+----------------------+
# |           4 | Russ                                    | Big Sean, Sabrina Claudio                | 07-08-2025 | Red Rocks            |
# +-------------+-----------------------------------------+------------------------------------------+------------+----------------------+
# |           3 | Borgore                                 |                                          | 05-29-2025 | The Church Nightclub |
# +-------------+-----------------------------------------+------------------------------------------+------------+----------------------+
# |           3 | Halsey                                  | Magdalena Bay, flowerolove               | 06-22-2025 | Red Rocks            |
# +-------------+-----------------------------------------+------------------------------------------+------------+----------------------+
# |           3 | Vanic                                   |                                          | 08-16-2025 | Meow Wolf            |
# +-------------+-----------------------------------------+------------------------------------------+------------+----------------------+
# |           3 | d4vd                                    | Yung Kai                                 | 09-12-2025 | Mission Ballroom     |
# +-------------+-----------------------------------------+------------------------------------------+------------+----------------------+
# |           3 | Carl Cox Evolution Live                 | Vintage Culture, ANNA, Bontan, The       | 10-13-2025 | Red Rocks            |
# |             |                                         | Bordas Brothers                          |            |                      |
# +-------------+-----------------------------------------+------------------------------------------+------------+----------------------+
# |           3 | Claude VonStroke                        |                                          | 05-30-2025 | The Church Nightclub |
# +-------------+-----------------------------------------+------------------------------------------+------------+----------------------+
# |           3 | WHALES                                  |                                          | 07-04-2025 | Club Vinyl           |
# +-------------+-----------------------------------------+------------------------------------------+------------+----------------------+
# |           3 | Rated R                                 |                                          | 05-30-2025 | Club Vinyl           |
# +-------------+-----------------------------------------+------------------------------------------+------------+----------------------+
# |           3 | This Will Destroy You                   | Jesse Beaman                             | 07-20-2025 | Meow Wolf            |
# +-------------+-----------------------------------------+------------------------------------------+------------+----------------------+
# |           3 | Stick Figure                            | Stephen Marley, The Hip Abduction        | 06-12-2025 | Red Rocks            |
# +-------------+-----------------------------------------+------------------------------------------+------------+----------------------+
# |           3 | ERIC CHURCH vs THE MACHINE              | with special guest Stephen Wilson Jr.    | 07-14-2025 | Red Rocks            |
# +-------------+-----------------------------------------+------------------------------------------+------------+----------------------+
# |           3 | ERIC CHURCH vs THE ECB                  | with special guest Stephen Wilson Jr.    | 07-15-2025 | Red Rocks            |
# +-------------+-----------------------------------------+------------------------------------------+------------+----------------------+
# |           3 | ERIC CHURCH vs THE GUITAR               | with special guest Stephen Wilson Jr.    | 07-16-2025 | Red Rocks            |
# +-------------+-----------------------------------------+------------------------------------------+------------+----------------------+
# |           3 | Stick Figure                            | Stephen Marley, The Hip Abduction        | 06-10-2025 | Mission Ballroom     |
# +-------------+-----------------------------------------+------------------------------------------+------------+----------------------+
# |           2 | EDX                                     |                                          | 06-07-2025 | Club Vinyl           |
# +-------------+-----------------------------------------+------------------------------------------+------------+----------------------+
# |           2 | Will Clarke                             |                                          | 07-04-2025 | Club Vinyl           |
# +-------------+-----------------------------------------+------------------------------------------+------------+----------------------+
# |           2 | Big Wild                                |                                          | 09-27-2025 | Mission Ballroom     |
# +-------------+-----------------------------------------+------------------------------------------+------------+----------------------+
# |           2 | Thievery Corporation                    | Beats Antique, Moontricks                | 06-04-2025 | Red Rocks            |
# +-------------+-----------------------------------------+------------------------------------------+------------+----------------------+
# |           2 | Genesi, Dark Heart                      |                                          | 08-30-2025 | Club Vinyl           |
# +-------------+-----------------------------------------+------------------------------------------+------------+----------------------+
# |           2 | INFEKT Presents: Port Zero              |                                          | 12-13-2025 | Mission Ballroom     |
# +-------------+-----------------------------------------+------------------------------------------+------------+----------------------+
# |           2 | Eli & Fur                               |                                          | 05-31-2025 | Club Vinyl           |
# +-------------+-----------------------------------------+------------------------------------------+------------+----------------------+
# |           2 | Mau P                                   | Adam Beyer, ChaseWest, Decker Rush       | 11-15-2025 | Red Rocks            |
# +-------------+-----------------------------------------+------------------------------------------+------------+----------------------+
# |           2 | Jigitz                                  |                                          | 10-10-2025 | Club Vinyl           |
# +-------------+-----------------------------------------+------------------------------------------+------------+----------------------+
# |           2 | Jigitz                                  |                                          | 10-10-2025 | Club Vinyl           |
# +-------------+-----------------------------------------+------------------------------------------+------------+----------------------+
# |           2 | Charley Crockett                        | Chaparelle, Rattlesnake Milk             | 06-25-2025 | Red Rocks            |
# +-------------+-----------------------------------------+------------------------------------------+------------+----------------------+
# |           2 | Jordan Davis                            | Mitchell Tenpenny, Vincent Mason         | 09-24-2025 | Red Rocks            |
# +-------------+-----------------------------------------+------------------------------------------+------------+----------------------+
# |           2 | Reggae On The Rocks 2025                | Rebelution, SOJA, Tarrus Riley, Kabaka   | 08-23-2025 | Red Rocks            |
# |             |                                         | Pyramid, Rik Jam, Judge Roughneck        |            |                      |
# +-------------+-----------------------------------------+------------------------------------------+------------+----------------------+
# |           2 | Kyle Walker, RUZE, Latmun               |                                          | 06-07-2025 | Club Vinyl           |
# +-------------+-----------------------------------------+------------------------------------------+------------+----------------------+
# |           1 | Charles Wesley Godwin                   | Ole 60, The Castellows                   | 10-15-2025 | Red Rocks            |
# +-------------+-----------------------------------------+------------------------------------------+------------+----------------------+
# |           1 | The Struts                              | with Special Guest Dirty Honey           | 09-23-2025 | Ogden Theatre        |
# +-------------+-----------------------------------------+------------------------------------------+------------+----------------------+
# |           1 | Smallpools                              |                                          | 11-07-2025 | Meow Wolf            |
# +-------------+-----------------------------------------+------------------------------------------+------------+----------------------+
# |           1 | Audien                                  |                                          | 09-19-2025 | The Church Nightclub |
# +-------------+-----------------------------------------+------------------------------------------+------------+----------------------+
# |           1 | Sickick                                 |                                          | 06-27-2025 | The Church Nightclub |
# +-------------+-----------------------------------------+------------------------------------------+------------+----------------------+
# |           1 | Jerry Garcia Symphonic Celebration      | featuring Melvin Seals, Jacklyn          | 07-06-2025 | Red Rocks            |
# |             |                                         | LaBranch, Oteil Burbridge, Tom Hamilton, |            |                      |
# |             |                                         | Duane Trucks and Lady...                 |            |                      |
# +-------------+-----------------------------------------+------------------------------------------+------------+----------------------+
# |           1 | LCD Soundsystem                         | TV On The Radio                          | 08-13-2025 | Red Rocks            |
# +-------------+-----------------------------------------+------------------------------------------+------------+----------------------+
# |           1 | Hippie Sabotage – Rescheduled           | Two Feet, Kal Banx                       | 08-22-2025 | Red Rocks            |
# +-------------+-----------------------------------------+------------------------------------------+------------+----------------------+
# |           1 | Alison Krauss & Union Station featuring |                                          | 06-18-2025 | Red Rocks            |
# |             | Jerry Douglas                           |                                          |            |                      |
# +-------------+-----------------------------------------+------------------------------------------+------------+----------------------+
# |           1 | Parker McCollum Tour                    | Kameron Marlowe, Hudson Westbrook        | 07-31-2025 | Red Rocks            |
# +-------------+-----------------------------------------+------------------------------------------+------------+----------------------+
# |           1 | Sheryl Crow                             | Larkin Poe                               | 06-10-2025 | Red Rocks            |
# +-------------+-----------------------------------------+------------------------------------------+------------+----------------------+
# |           1 | Something Corporate, Jack’s Mannequin,  |                                          | 07-23-2025 | Red Rocks            |
# |             | Andrew McMahon in the Wilderness        |                                          |            |                      |
# +-------------+-----------------------------------------+------------------------------------------+------------+----------------------+
# |           1 | TOKiMONSTA, Danny Daze                  |                                          | 08-23-2025 | Club Vinyl           |
# +-------------+-----------------------------------------+------------------------------------------+------------+----------------------+
# |           1 | Ashe                                    | Bo Staloch                               | 06-13-2025 | Ogden Theatre        |
# +-------------+-----------------------------------------+------------------------------------------+------------+----------------------+
# |           1 | Nurko                                   |                                          | 08-23-2025 | Ogden Theatre        |
# +-------------+-----------------------------------------+------------------------------------------+------------+----------------------+
# |           1 | O.A.R.                                  | Blind Melon                              | 06-21-2025 | Red Rocks            |
# +-------------+-----------------------------------------+------------------------------------------+------------+----------------------+
# |           1 | Space Bacon                             | Giant Walking Robots                     | 06-27-2025 | Meow Wolf            |
# +-------------+-----------------------------------------+------------------------------------------+------------+----------------------+
# |           1 | Flying Lotus & Reggie Watts             | Music, Comedy Live Art & More!           | 06-17-2025 | Mission Ballroom     |
# +-------------+-----------------------------------------+------------------------------------------+------------+----------------------+
# |           1 | Atmosphere & Friends                    | Hieroglyphics, Dilated Peoples, Living   | 09-19-2025 | Red Rocks            |
# |             |                                         | Legends, Immortal Technique,             |            |                      |
# |             |                                         | CunninLynguists, DeeJayBird              |            |                      |
# +-------------+-----------------------------------------+------------------------------------------+------------+----------------------+
# |           1 | Ilan Bluestone                          |                                          | 07-18-2025 | The Church Nightclub |
# +-------------+-----------------------------------------+------------------------------------------+------------+----------------------+
# |           1 | Bear Grillz                             |                                          | 08-16-2025 | Ogden Theatre        |
# +-------------+-----------------------------------------+------------------------------------------+------------+----------------------+
# |           1 | The Story So Far                        | Neck Deep, Origami Angel, Pain of Truth  | 10-07-2025 | Mission Ballroom     |
# +-------------+-----------------------------------------+------------------------------------------+------------+----------------------+
# |           1 | Rainbow ROLL – Pride Celebration        | Sip, Slay, Skate & Sing this Pride       | 06-20-2025 | ReelWorks            |
# |             |                                         | Month!                                   |            |                      |
# +-------------+-----------------------------------------+------------------------------------------+------------+----------------------+
# |           1 | Trevor Hall                             | The Barr Brothers, Fruit Bats (Solo),    | 06-15-2025 | Red Rocks            |
# |             |                                         | East Forest (DJ Set)                     |            |                      |
# +-------------+-----------------------------------------+------------------------------------------+------------+----------------------+
# |           1 | Teddy Swims                             | Cian Ducrot                              | 08-26-2025 | Red Rocks            |
# +-------------+-----------------------------------------+------------------------------------------+------------+----------------------+
# |           1 | Mason Collective                        |                                          | 06-28-2025 | Club Vinyl           |
# +-------------+-----------------------------------------+------------------------------------------+------------+----------------------+
# |           1 | The Kooks                               | lovelytheband                            | 06-13-2025 | Mission Ballroom     |
# +-------------+-----------------------------------------+------------------------------------------+------------+----------------------+
# |           1 | Dylan Gossett                           | Willow Avalon, Buffalo Traffic Jam       | 11-09-2025 | Mission Ballroom     |
# +-------------+-----------------------------------------+------------------------------------------+------------+----------------------+
# |           1 | EMBRZ: Another Round                    |                                          | 08-16-2025 | Club Vinyl           |
# +-------------+-----------------------------------------+------------------------------------------+------------+----------------------+
# |           1 | Sex Pistols (Steve Jones, Paul Cook,    | The Molotovs                             | 10-10-2025 | Mission Ballroom     |
# |             | Glen Matlock) Feat. Frank Carter        |                                          |            |                      |
# +-------------+-----------------------------------------+------------------------------------------+------------+----------------------+
# |           1 | Bryan Kearney + Paul Denton             |                                          | 07-25-2025 | Club Vinyl           |
# +-------------+-----------------------------------------+------------------------------------------+------------+----------------------+
# |           1 | YUNGBLUD                                | Sawyer Hill                              | 08-28-2025 | Mission Ballroom     |
# +-------------+-----------------------------------------+------------------------------------------+------------+----------------------+
# |           1 | My Morning Jacket                       | Melt                                     | 08-15-2025 | Red Rocks            |
# +-------------+-----------------------------------------+------------------------------------------+------------+----------------------+
# |           1 | My Morning Jacket                       | Melt                                     | 08-16-2025 | Red Rocks            |
# +-------------+-----------------------------------------+------------------------------------------+------------+----------------------+
# |           1 | Beck with the Colorado Symphony         | with support Molly Lewis                 | 07-27-2025 | Red Rocks            |
# +-------------+-----------------------------------------+------------------------------------------+------------+----------------------+
# |           1 | Slightly Stoopid                        | Iration, Collie Buddz, Little Stranger   | 08-09-2025 | Red Rocks            |
# +-------------+-----------------------------------------+------------------------------------------+------------+----------------------+
# |           1 | Tennis                                  | Real Estate                              | 08-26-2025 | Mission Ballroom     |
# +-------------+-----------------------------------------+------------------------------------------+------------+----------------------+
# |           1 | Tash Sultana                            |                                          | 06-20-2025 | Red Rocks            |
# +-------------+-----------------------------------------+------------------------------------------+------------+----------------------+
# |           1 | Rainbow Kitten Surprise                 | Medium Build                             | 09-08-2025 | Red Rocks            |
# +-------------+-----------------------------------------+------------------------------------------+------------+----------------------+
# |           1 | Dirty Heads                             | Rome, Tropidelic                         | 06-26-2025 | Red Rocks            |
# +-------------+-----------------------------------------+------------------------------------------+------------+----------------------+
